# %% [markdown]
# ### Fetch Rewards Coding Exercise - Data Analyst
#
# #### Preprocessing
#
# ##### Receipts Data

# %%
##Importing libraries
import json
import pandas as pd
import numpy as np
from flatten_json import flatten
from datetime import datetime
from pandas_profiling import ProfileReport

# %%
##Load Receipts json file
receipts = pd.read_json('receipts.json', lines= True)
receipts.head()
# Out:
#                                     _id  bonusPointsEarned  \
# 0  {'$oid': '5ff1e1eb0a720f0523000575'}              500.0
# 1  {'$oid': '5ff1e1bb0a720f052300056b'}              150.0
# 2  {'$oid': '5ff1e1f10a720f052300057a'}                5.0
# 3  {'$oid': '5ff1e1ee0a7214ada100056f'}                5.0
# 4  {'$oid': '5ff1e1d20a7214ada1000561'}                5.0
#
#                              bonusPointsEarnedReason  \
# 0  Receipt number 2 completed, bonus point schedu...
# 1  Receipt number 5 completed, bonus point schedu...
# 2                         All-receipts receipt bonus
# 3                         All-receipts receipt bonus
# 4                         All-receipts receipt bonus
#
#                  createDate               dateScanned  \
# 0  {'$date': 1609687531000}  {'$date': 1609687531000}
# 1  {'$date': 1609687483000}  {'$date': 1609687483000}
# 2  {'$date': 1609687537000}  {'$date': 1609687537000}
# 3  {'$date': 1609687534000}  {'$date': 1609687534000}
# ...

# %%
receipts.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1119 entries, 0 to 1118
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   _id                      1119 non-null   object
#  1   bonusPointsEarned        544 non-null    float64
#  2   bonusPointsEarnedReason  544 non-null    object
#  3   createDate               1119 non-null   object
#  4   dateScanned              1119 non-null   object
#  5   finishedDate             568 non-null    object
#  6   modifyDate               1119 non-null   object
#  7   pointsAwardedDate        537 non-null    object
#  8   pointsEarned             609 non-null    float64
#  9   purchaseDate             671 non-null    object
#  10  purchasedItemCount       635 non-null    float64
#  11  rewardsReceiptItemList   679 non-null    object
#  12  rewardsReceiptStatus     1119 non-null   object
#  13  totalSpent               684 non-null    float64
# ...

# %%
receipts.isnull().sum()
# Out:
# _id                          0
# bonusPointsEarned          575
# bonusPointsEarnedReason    575
# createDate                   0
# dateScanned                  0
# finishedDate               551
# modifyDate                   0
# pointsAwardedDate          582
# pointsEarned               510
# purchaseDate               448
# purchasedItemCount         484
# rewardsReceiptItemList     440
# rewardsReceiptStatus         0
# totalSpent                 435
# userId                       0
# dtype: int64

# %%
receipts.describe()
# Out:
#        bonusPointsEarned  pointsEarned  purchasedItemCount   totalSpent
# count         544.000000    609.000000           635.00000   684.000000
# mean          238.893382    585.962890            14.75748    77.796857
# std           299.091731   1357.166947            61.13424   347.110349
# min             5.000000      0.000000             0.00000     0.000000
# 25%             5.000000      5.000000             1.00000     1.000000
# 50%            45.000000    150.000000             2.00000    18.200000
# 75%           500.000000    750.000000             5.00000    34.960000
# max           750.000000  10199.800000           689.00000  4721.950000

# %%
###Function to parse the dates
def extract_dates(df, date_fields):
    for i in date_fields:
        df[i] = df[i].astype(str).str.extract('(\d+)').fillna(0)
        df[i] = df[i].apply(lambda time: (datetime.fromtimestamp(int(time)/1000)).strftime("%Y-%m-%d %H:%M:%S"))
    return df

# %%
receipts["_id"] = pd.json_normalize(receipts["_id"])
receipt_id = receipts.pop('_id')
receipts.insert(0, 'receipt_id', receipt_id)
date_fields = ['createDate', 'dateScanned', 'finishedDate', 'modifyDate', 'pointsAwardedDate', 'purchaseDate', ]
receipts_df = extract_dates(receipts, date_fields)

# %%
receipts_df.head()
# Out:
#                  receipt_id  bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
# 3  5ff1e1ee0a7214ada100056f                5.0
# 4  5ff1e1d20a7214ada1000561                5.0
#
#                              bonusPointsEarnedReason           createDate  \
# 0  Receipt number 2 completed, bonus point schedu...  2021-01-03 10:25:31
# 1  Receipt number 5 completed, bonus point schedu...  2021-01-03 10:24:43
# 2                         All-receipts receipt bonus  2021-01-03 10:25:37
# 3                         All-receipts receipt bonus  2021-01-03 10:25:34
# 4                         All-receipts receipt bonus  2021-01-03 10:25:06
#
#            dateScanned         finishedDate           modifyDate  \
# 0  2021-01-03 10:25:31  2021-01-03 10:25:31  2021-01-03 10:25:36
# 1  2021-01-03 10:24:43  2021-01-03 10:24:43  2021-01-03 10:24:48
# ...

# %%
###Create a new dataframe from the RewardReceiptItemList column from receipt data
def extract_reward_receipt(df, col_list):
    df = df.explode('rewardsReceiptItemList')
    df = df[col_list]
    df = pd.json_normalize(json.loads(df.to_json(orient= 'records')))
    df.drop(['rewardsReceiptItemList'], axis=1, inplace= True)
    df.columns= df.columns.str.split('.').str[-1]
    df.insert(0, 'reward_id', df.index +1)
    return df

# %%
col_list = ['receipt_id','rewardsReceiptItemList']
rewardsReceiptItemList = extract_reward_receipt(receipts_df, col_list)

# %%
rewardsReceiptItemList.head()
# Out:
#    reward_id                receipt_id       barcode  \
# 0          1  5ff1e1eb0a720f0523000575          4011
# 1          2  5ff1e1bb0a720f052300056b          4011
# 2          3  5ff1e1bb0a720f052300056b  028400642255
# 3          4  5ff1e1f10a720f052300057a           NaN
# 4          5  5ff1e1ee0a7214ada100056f          4011
#
#                                          description finalPrice itemPrice  \
# 0                                     ITEM NOT FOUND      26.00     26.00
# 1                                     ITEM NOT FOUND          1         1
# 2  DORITOS TORTILLA CHIP SPICY SWEET CHILI REDUCE...      10.00     10.00
# 3                                                NaN        NaN       NaN
# 4                                     ITEM NOT FOUND      28.00     28.00
#
#   needsFetchReview partnerItemId preventTargetGapPoints  quantityPurchased  \
# 0            False             1                   True                5.0
# ...

# %%
rewardsReceiptItemList.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7381 entries, 0 to 7380
# Data columns (total 36 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   reward_id                           7381 non-null   int64
#  1   receipt_id                          7381 non-null   object
#  2   barcode                             3090 non-null   object
#  3   description                         6560 non-null   object
#  4   finalPrice                          6767 non-null   object
#  5   itemPrice                           6767 non-null   object
#  6   needsFetchReview                    813 non-null    object
#  7   partnerItemId                       6941 non-null   object
#  8   preventTargetGapPoints              358 non-null    object
#  9   quantityPurchased                   6767 non-null   float64
#  10  userFlaggedBarcode                  337 non-null    object
# ...

# %%
rewardsReceiptItemList.describe()
# Out:
#          reward_id  quantityPurchased  userFlaggedQuantity  \
# count  7381.000000        6767.000000           299.000000
# mean   3691.000000           1.386139             1.872910
# std    2130.855501           1.204363             1.314823
# min       1.000000           1.000000             1.000000
# 25%    1846.000000           1.000000             1.000000
# 50%    3691.000000           1.000000             1.000000
# 75%    5536.000000           1.000000             3.000000
# max    7381.000000          17.000000             5.000000
#
#        originalMetaBriteQuantityPurchased
# count                           15.000000
# mean                             1.200000
# std                              0.414039
# min                              1.000000
# 25%                              1.000000
# 50%                              1.000000
# 75%                              1.000000
# max                              2.000000

# %%
rewardsReceiptItemList.isnull().sum()
# Out:
# reward_id                                0
# receipt_id                               0
# barcode                               4291
# description                            821
# finalPrice                             614
# itemPrice                              614
# needsFetchReview                      6568
# partnerItemId                          440
# preventTargetGapPoints                7023
# quantityPurchased                      614
# userFlaggedBarcode                    7044
# userFlaggedNewItem                    7058
# userFlaggedPrice                      7082
# userFlaggedQuantity                   7082
# needsFetchReviewReason                7162
# pointsNotAwardedReason                7041
# pointsPayerId                         6114
# rewardsGroup                          5650
# rewardsProductPartnerId               5112
# userFlaggedDescription                7176
# originalMetaBriteBarcode              7310
# originalMetaBriteDescription          7371
# ...

# %%
receipts_df.drop(['rewardsReceiptItemList'], axis=1, inplace = True)
receipts_df.head()
# Out:
#                  receipt_id  bonusPointsEarned  \
# 0  5ff1e1eb0a720f0523000575              500.0
# 1  5ff1e1bb0a720f052300056b              150.0
# 2  5ff1e1f10a720f052300057a                5.0
# 3  5ff1e1ee0a7214ada100056f                5.0
# 4  5ff1e1d20a7214ada1000561                5.0
#
#                              bonusPointsEarnedReason           createDate  \
# 0  Receipt number 2 completed, bonus point schedu...  2021-01-03 10:25:31
# 1  Receipt number 5 completed, bonus point schedu...  2021-01-03 10:24:43
# 2                         All-receipts receipt bonus  2021-01-03 10:25:37
# 3                         All-receipts receipt bonus  2021-01-03 10:25:34
# 4                         All-receipts receipt bonus  2021-01-03 10:25:06
#
#            dateScanned         finishedDate           modifyDate  \
# 0  2021-01-03 10:25:31  2021-01-03 10:25:31  2021-01-03 10:25:36
# 1  2021-01-03 10:24:43  2021-01-03 10:24:43  2021-01-03 10:24:48
# ...

# %%
receipts_df.to_csv('receipts.csv', index=False)

# %%
rewardsReceiptItemList.to_csv('rewardsReceiptItemList.csv', index=False)

# %% [markdown]
# ##### Users Data

# %%
users = pd.read_json('users.json', lines= True)
users["_id"] = pd.json_normalize(users["_id"])
user_id = users.pop('_id')
users.insert(0, 'user_id', user_id)
users.head()
# Out:
#                     user_id  active               createdDate  \
# 0  5ff1e194b6a9d73a3a9f1052    True  {'$date': 1609687444800}
# 1  5ff1e194b6a9d73a3a9f1052    True  {'$date': 1609687444800}
# 2  5ff1e194b6a9d73a3a9f1052    True  {'$date': 1609687444800}
# 3  5ff1e1eacfcf6c399c274ae6    True  {'$date': 1609687530554}
# 4  5ff1e194b6a9d73a3a9f1052    True  {'$date': 1609687444800}
#
#                   lastLogin      role signUpSource state
# 0  {'$date': 1609687537858}  consumer        Email    WI
# 1  {'$date': 1609687537858}  consumer        Email    WI
# 2  {'$date': 1609687537858}  consumer        Email    WI
# 3  {'$date': 1609687530597}  consumer        Email    WI
# 4  {'$date': 1609687537858}  consumer        Email    WI

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495 entries, 0 to 494
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   user_id       495 non-null    object
#  1   active        495 non-null    bool
#  2   createdDate   495 non-null    object
#  3   lastLogin     433 non-null    object
#  4   role          495 non-null    object
#  5   signUpSource  447 non-null    object
#  6   state         439 non-null    object
# dtypes: bool(1), object(6)
# memory usage: 23.8+ KB

# %%
users.describe()
# Out:
#                          user_id active               createdDate  \
# count                        495    495                       495
# unique                       212      2                       212
# top     54943462e4b07e684157a532   True  {'$date': 1418998882381}
# freq                          20    494                        20
#
#                        lastLogin      role signUpSource state
# count                        433       495          447   439
# unique                       172         2            2     8
# top     {'$date': 1614379156799}  consumer        Email    WI
# freq                          20       413          443   396

# %%
users.isnull().sum()
# Out:
# user_id          0
# active           0
# createdDate      0
# lastLogin       62
# role             0
# signUpSource    48
# state           56
# dtype: int64

# %%
date_fields = ['createdDate', 'lastLogin']
users_df = extract_dates(users, date_fields)

# %%
users_df.head()
# Out:
#                     user_id  active          createdDate            lastLogin  \
# 0  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04  2021-01-03 10:25:37
# 1  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04  2021-01-03 10:25:37
# 2  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04  2021-01-03 10:25:37
# 3  5ff1e1eacfcf6c399c274ae6    True  2021-01-03 10:25:30  2021-01-03 10:25:30
# 4  5ff1e194b6a9d73a3a9f1052    True  2021-01-03 10:24:04  2021-01-03 10:25:37
#
#        role signUpSource state
# 0  consumer        Email    WI
# 1  consumer        Email    WI
# 2  consumer        Email    WI
# 3  consumer        Email    WI
# 4  consumer        Email    WI

# %%
users_df = users_df.drop_duplicates('user_id', keep='last')
users_df.to_csv('users.csv', index=False)

# %% [markdown]
# #### Brand Data

# %%
brands = pd.read_json('brands.json', lines= True)
brands.head()
# Out:
#                                     _id       barcode        category  \
# 0  {'$oid': '601ac115be37ce2ead437551'}  511111019862          Baking
# 1  {'$oid': '601c5460be37ce2ead43755f'}  511111519928       Beverages
# 2  {'$oid': '601ac142be37ce2ead43755d'}  511111819905          Baking
# 3  {'$oid': '601ac142be37ce2ead43755a'}  511111519874          Baking
# 4  {'$oid': '601ac142be37ce2ead43755e'}  511111319917  Candy & Sweets
#
#        categoryCode                                                cpg  \
# 0            BAKING  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1         BEVERAGES  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  CANDY_AND_SWEETS  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name  topBrand                      brandCode
# ...

# %%
brands['topBrand']=brands['topBrand'].apply(lambda x: 'True' if x==1.0 else 'False' if x==0.0 else x)

# %%
brands['topBrand'].unique()
# Out:
# array(['False', nan, 'True'], dtype=object)

# %%
brands.head()
# Out:
#                                     _id       barcode        category  \
# 0  {'$oid': '601ac115be37ce2ead437551'}  511111019862          Baking
# 1  {'$oid': '601c5460be37ce2ead43755f'}  511111519928       Beverages
# 2  {'$oid': '601ac142be37ce2ead43755d'}  511111819905          Baking
# 3  {'$oid': '601ac142be37ce2ead43755a'}  511111519874          Baking
# 4  {'$oid': '601ac142be37ce2ead43755e'}  511111319917  Candy & Sweets
#
#        categoryCode                                                cpg  \
# 0            BAKING  {'$id': {'$oid': '601ac114be37ce2ead437550'}, ...
# 1         BEVERAGES  {'$id': {'$oid': '5332f5fbe4b03c9a25efd0ba'}, ...
# 2            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 3            BAKING  {'$id': {'$oid': '601ac142be37ce2ead437559'}, ...
# 4  CANDY_AND_SWEETS  {'$id': {'$oid': '5332fa12e4b03c9a25efd1e7'}, ...
#
#                         name topBrand                      brandCode
# ...

# %%
brands["_id"] = pd.json_normalize(brands["_id"])
brands_cpg = pd.json_normalize(brands['cpg'])

# %%
brands_cpg.columns
# Out:
# Index(['$ref', '$id.$oid'], dtype='object')

# %%
brands['cpg_ref'] = brands_cpg['$ref']
brands['cpg'] = brands_cpg['$id.$oid']

# %%
brand_id = brands.pop('_id')
brands.insert(0, 'brand_id', brand_id)

# %%
brands.head()
# Out:
#                    brand_id       barcode        category      categoryCode  \
# 0  601ac115be37ce2ead437551  511111019862          Baking            BAKING
# 1  601c5460be37ce2ead43755f  511111519928       Beverages         BEVERAGES
# 2  601ac142be37ce2ead43755d  511111819905          Baking            BAKING
# 3  601ac142be37ce2ead43755a  511111519874          Baking            BAKING
# 4  601ac142be37ce2ead43755e  511111319917  Candy & Sweets  CANDY_AND_SWEETS
#
#                         cpg                       name topBrand  \
# 0  601ac114be37ce2ead437550  test brand @1612366101024    False
# 1  5332f5fbe4b03c9a25efd0ba                  Starbucks    False
# 2  601ac142be37ce2ead437559  test brand @1612366146176    False
# 3  601ac142be37ce2ead437559  test brand @1612366146051    False
# 4  5332fa12e4b03c9a25efd1e7  test brand @1612366146827    False
#
#                        brandCode cpg_ref
# 0                            NaN    Cogs
# ...

# %%
brands.to_csv('brands.csv', index=False)

# %%
brands.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1167 entries, 0 to 1166
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand_id      1167 non-null   object
#  1   barcode       1167 non-null   int64
#  2   category      1012 non-null   object
#  3   categoryCode  517 non-null    object
#  4   cpg           1167 non-null   object
#  5   name          1167 non-null   object
#  6   topBrand      555 non-null    object
#  7   brandCode     933 non-null    object
#  8   cpg_ref       1167 non-null   object
# dtypes: int64(1), object(8)
# memory usage: 82.2+ KB

# %%
brands.isnull().sum()
# Out:
# brand_id          0
# barcode           0
# category        155
# categoryCode    650
# cpg               0
# name              0
# topBrand        612
# brandCode       234
# cpg_ref           0
# dtype: int64
